# %% [markdown]
# ### **RAG BASED TEACHING AI ASSISTANT**

# %% [markdown]
# **🧠 Cell 1 Description:**
#
# This cell sets up the environment for offline speech recognition using the Vosk library. It installs all necessary dependencies such as vosk, soundfile, pydub, tqdm, and ffmpeg, ensuring that audio files can be processed and transcribed locally without relying on online APIs.

# %%
# ✅ Cell 1: Install and configure Vosk (offline speech recognition)


# Upgrade pip and install required packages
# !pip install -q --upgrade pip

# Install Vosk (offline speech-to-text) and helpers
# !pip install -q vosk soundfile pydub tqdm ffmpeg-python

# Ensure ffmpeg is available
# !which ffmpeg || (apt-get update -qq && apt-get install -y -qq ffmpeg)

# !pip install -q sentence-transformers

print("\n✅ Installed Vosk + dependencies successfully.")
print("You can now run the next cell to download a model and transcribe audio files.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for srt (pyproject.toml) ... done
# /usr/bin/ffmpeg
#
# ✅ Installed Vosk + dependencies successfully.
# You can now run the next cell to download a model and transcribe audio files.

# %% [markdown]
# **📂 Cell 2 Description:**
#
# This cell mounts your Google Drive and automatically imports a project folder from a shared Drive URL or folder ID into the Colab environment. It authenticates with Google, retrieves files (including Google Docs/Sheets via export), and downloads them recursively into a local directory (/content/RAG-Based-AI-Teaching-Assistant). This ensures your entire project is accessible within Colab for further processing or execution.

# %%
# Cell 2 (updated) - Mount Drive and import project from a Drive folder URL or ID
from google.colab import drive, auth
import os, re, io
from pathlib import Path
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload

# 1) Mount Drive
drive.mount('/content/drive', force_remount=True)

# 2) Helper: extract folder id from a Drive URL or accept an ID
def extract_folder_id(s: str):
    # common URL forms:
    # https://drive.google.com/drive/folders/<ID>?...
    # https://drive.google.com/drive/u/0/folders/<ID>
    m = re.search(r'folders/([a-zA-Z0-9_\-]+)', s)
    if m:
        return m.group(1)
    # if user pasted only the id
    if re.fullmatch(r'[a-zA-Z0-9_\-]+', s):
        return s
    return None

folder_input = "https://drive.google.com/drive/folders/16D3GyqZNQIVgtyVOHVgatWLg36aepm8e?usp=drive_link"

FOLDER_ID = extract_folder_id(folder_input)
if not FOLDER_ID:
    raise SystemExit("Couldn't parse a folder ID from folder_input. Put the full folder URL or the folder ID in folder_input variable.")

print("Parsed folder id:", FOLDER_ID)

# 3) Try to find the folder under /content/drive/MyDrive (if user added shortcut or it's in My Drive)
def find_path_in_mydrive_by_name(folder_id):
    # Quick heuristic scan: look for folders with this ID in MyDrive using file metadata is not available
    # Instead try to find a folder with the same folder name if it exists
    # This is best-effort; if file is not in MyDrive we'll fallback to Drive API download.
    base = Path("/content/drive/MyDrive")
    if not base.exists():
        return None
    # Walk a little and try to match folder id in the folder url metadata is not available on FUSE,
    # so we can't reliably map ID -> path. Return None to force Drive API fallback.
    return None

mydrive_path = find_path_in_mydrive_by_name(FOLDER_ID)
if mydrive_path:
    PROJECT_DIR = str(mydrive_path)
    print("Found folder in My Drive at:", PROJECT_DIR)
else:
    print("Folder not found in My Drive FUSE path — will use Drive API to copy files locally.")

    # 4) Authenticate and build Drive API client
    auth.authenticate_user()
    drive_service = build('drive', 'v3')

    # 5) Create local target dir
    LOCAL_PROJECT_DIR = "/content/RAG-Based-AI-Teaching-Assistant"
    Path(LOCAL_PROJECT_DIR).mkdir(parents=True, exist_ok=True)

    # 6) Recursively download folder contents from Drive folder id -> LOCAL_PROJECT_DIR
    def download_file(file_id, dest_path, mimeType=None):
        """Download a regular file to dest_path. Handles binary content."""
        request = drive_service.files().get_media(fileId=file_id)
        fh = io.FileIO(dest_path, mode='wb')
        downloader = MediaIoBaseDownload(fh, request)
        done = False
        while not done:
            status, done = downloader.next_chunk()
            # optional: print(f"Download {dest_path}: {int(status.progress()*100)}%")
        fh.close()

    def export_google_doc(file_id, dest_path, mimeType='text/plain'):
        """Export Google Docs/Sheets/... to a usable format (text/plain/pdf)"""
        request = drive_service.files().export_media(fileId=file_id, mimeType=mimeType)
        fh = io.FileIO(dest_path, mode='wb')
        downloader = MediaIoBaseDownload(fh, request)
        done = False
        while not done:
            status, done = downloader.next_chunk()
        fh.close()

    def list_children(folder_id):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        while True:
            res = drive_service.files().list(q=query,
                                            spaces='drive',
                                            fields='nextPageToken, files(id, name, mimeType)',
                                            pageToken=page_token).execute()
            items = res.get('files', [])
            files.extend(items)
            page_token = res.get('nextPageToken', None)
            if not page_token:
                break
        return files

    def download_folder_recursive(folder_id, dest_dir):
        items = list_children(folder_id)
        for it in items:
            fid = it['id']
            name = it['name']
            mime = it.get('mimeType', '')
            safe_name = name.replace('/', '_')
            dest = os.path.join(dest_dir, safe_name)
            if mime == 'application/vnd.google-apps.folder':
                os.makedirs(dest, exist_ok=True)
                print("Creating folder:", dest)
                download_folder_recursive(fid, dest)
            elif mime.startswith('application/vnd.google-apps'):
                # Google-native file (Docs/Sheets/Slides). Try exporting as plain text or PDF.
                print("Exporting Google native file:", name, "->", dest + ".txt")
                try:
                    export_google_doc(fid, dest + ".txt", mimeType='text/plain')
                except Exception as e:
                    print("  export as text failed, trying pdf:", e)
                    try:
                        export_google_doc(fid, dest + ".pdf", mimeType='application/pdf')
                    except Exception as e2:
                        print("  export failed:", e2)
            else:
                # Regular file -> download
                print("Downloading file:", name, "->", dest)
                try:
                    download_file(fid, dest, mimeType=mime)
                except Exception as e:
                    print("  download error:", e)

    print("Downloading contents of Drive folder to:", LOCAL_PROJECT_DIR)
    download_folder_recursive(FOLDER_ID, LOCAL_PROJECT_DIR)
    PROJECT_DIR = LOCAL_PROJECT_DIR

# 7) Change working directory to project dir & list files
print("Using PROJECT_DIR =", PROJECT_DIR)
os.chdir(PROJECT_DIR)
print("Current working directory:")
# !pwd
print("\nFiles in project directory (top-level):")
# !ls -la | sed -n '1,120p'
# Out:
# Mounted at /content/drive
# Parsed folder id: 16D3GyqZNQIVgtyVOHVgatWLg36aepm8e
# Folder not found in My Drive FUSE path — will use Drive API to copy files locally.
# Downloading contents of Drive folder to: /content/RAG-Based-AI-Teaching-Assistant
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/logs
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/logs/refs
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/logs/refs/remotes
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/logs/refs/remotes/origin
# Downloading file: HEAD -> /content/RAG-Based-AI-Teaching-Assistant/.git/logs/refs/remotes/origin/HEAD
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/logs/refs/heads
# Downloading file: main -> /content/RAG-Based-AI-Teaching-Assistant/.git/logs/refs/heads/main
# Downloading file: HEAD -> /content/RAG-Based-AI-Teaching-Assistant/.git/logs/HEAD
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/objects
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/objects/pack
# Downloading file: pack-4d17799fefb505018b33f42169caf3f5dcc1625f.pack -> /content/RAG-Based-AI-Teaching-Assistant/.git/objects/pack/pack-4d17799fefb505018b33f42169caf3f5dcc1625f.pack
# Downloading file: pack-4d17799fefb505018b33f42169caf3f5dcc1625f.idx -> /content/RAG-Based-AI-Teaching-Assistant/.git/objects/pack/pack-4d17799fefb505018b33f42169caf3f5dcc1625f.idx
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/info
# Downloading file: exclude -> /content/RAG-Based-AI-Teaching-Assistant/.git/info/exclude
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/hooks
# Downloading file: pre-applypatch.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/pre-applypatch.sample
# Downloading file: post-update.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/post-update.sample
# Downloading file: pre-rebase.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/pre-rebase.sample
# Downloading file: pre-receive.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/pre-receive.sample
# Downloading file: push-to-checkout.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/push-to-checkout.sample
# Downloading file: pre-push.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/pre-push.sample
# Downloading file: pre-commit.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/pre-commit.sample
# Downloading file: fsmonitor-watchman.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/fsmonitor-watchman.sample
# Downloading file: applypatch-msg.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/applypatch-msg.sample
# Downloading file: pre-merge-commit.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/pre-merge-commit.sample
# Downloading file: commit-msg.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/commit-msg.sample
# Downloading file: prepare-commit-msg.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/prepare-commit-msg.sample
# Downloading file: update.sample -> /content/RAG-Based-AI-Teaching-Assistant/.git/hooks/update.sample
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/refs
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/refs/heads
# Downloading file: main -> /content/RAG-Based-AI-Teaching-Assistant/.git/refs/heads/main
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/refs/remotes
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.git/refs/remotes/origin
# Downloading file: HEAD -> /content/RAG-Based-AI-Teaching-Assistant/.git/refs/remotes/origin/HEAD
# Downloading file: config -> /content/RAG-Based-AI-Teaching-Assistant/.git/config
# Downloading file: HEAD -> /content/RAG-Based-AI-Teaching-Assistant/.git/HEAD
# Downloading file: packed-refs -> /content/RAG-Based-AI-Teaching-Assistant/.git/packed-refs
# Downloading file: index -> /content/RAG-Based-AI-Teaching-Assistant/.git/index
# Downloading file: description -> /content/RAG-Based-AI-Teaching-Assistant/.git/description
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging
# Downloading file: markers.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/markers.py
# Downloading file: _structures.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/_structures.py
# Downloading file: version.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/version.py
# Downloading file: requirements.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/requirements.py
# Downloading file: utils.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/utils.py
# Downloading file: _typing.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/_typing.py
# Downloading file: _compat.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/_compat.py
# Downloading file: __about__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/__about__.py
# Downloading file: tags.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/tags.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/__init__.py
# Downloading file: specifiers.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/specifiers.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/more_itertools
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/more_itertools/__init__.py
# Downloading file: more.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/more_itertools/more.py
# Downloading file: recipes.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/more_itertools/recipes.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/__init__.py
# Downloading file: ordered_set.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/ordered_set.py
# Downloading file: pyparsing.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_vendor/pyparsing.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command
# Downloading file: install.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/install.py
# Downloading file: bdist_wininst.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/bdist_wininst.py
# Downloading file: install_scripts.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/install_scripts.py
# Downloading file: build_clib.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/build_clib.py
# Downloading file: build.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/build.py
# Downloading file: register.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/register.py
# Downloading file: install_data.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/install_data.py
# Downloading file: upload.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/upload.py
# Downloading file: check.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/check.py
# Downloading file: sdist.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/sdist.py
# Downloading file: build_scripts.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/build_scripts.py
# Downloading file: py37compat.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/py37compat.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/__init__.py
# Downloading file: install_egg_info.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/install_egg_info.py
# Downloading file: bdist_msi.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/bdist_msi.py
# Downloading file: build_ext.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py
# Downloading file: install_lib.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/install_lib.py
# Downloading file: bdist.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/bdist.py
# Downloading file: install_headers.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/install_headers.py
# Downloading file: bdist_dumb.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/bdist_dumb.py
# Downloading file: clean.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/clean.py
# Downloading file: config.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/config.py
# Downloading file: build_py.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/build_py.py
# Downloading file: bdist_rpm.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/bdist_rpm.py
# Downloading file: msvccompiler.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/msvccompiler.py
# Downloading file: log.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/log.py
# Downloading file: versionpredicate.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/versionpredicate.py
# Downloading file: util.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/util.py
# Downloading file: ccompiler.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/ccompiler.py
# Downloading file: py38compat.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/py38compat.py
# Downloading file: filelist.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/filelist.py
# Downloading file: cygwinccompiler.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/cygwinccompiler.py
# Downloading file: version.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/version.py
# Downloading file: core.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/core.py
# Downloading file: archive_util.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/archive_util.py
# Downloading file: _msvccompiler.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/_msvccompiler.py
# Downloading file: dist.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/dist.py
# Downloading file: dep_util.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/dep_util.py
# Downloading file: cmd.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/cmd.py
# Downloading file: sysconfig.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/sysconfig.py
# Downloading file: py35compat.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/py35compat.py
# Downloading file: spawn.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/spawn.py
# Downloading file: unixccompiler.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/unixccompiler.py
# Downloading file: file_util.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/file_util.py
# Downloading file: fancy_getopt.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/fancy_getopt.py
# Downloading file: text_file.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/text_file.py
# Downloading file: msvc9compiler.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/msvc9compiler.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/__init__.py
# Downloading file: debug.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/debug.py
# Downloading file: errors.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/errors.py
# Downloading file: extension.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/extension.py
# Downloading file: bcppcompiler.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/bcppcompiler.py
# Downloading file: config.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/config.py
# Downloading file: dir_util.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_distutils/dir_util.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/extern
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/extern/__init__.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command
# Downloading file: upload.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/upload.py
# Downloading file: register.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/register.py
# Downloading file: bdist_rpm.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/bdist_rpm.py
# Downloading file: launcher manifest.xml -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/launcher manifest.xml
# Downloading file: setopt.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/setopt.py
# Downloading file: install.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/install.py
# Downloading file: saveopts.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/saveopts.py
# Downloading file: test.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/test.py
# Downloading file: alias.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/alias.py
# Downloading file: install_scripts.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/install_scripts.py
# Downloading file: easy_install.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/easy_install.py
# Downloading file: install_lib.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/install_lib.py
# Downloading file: build_ext.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/build_ext.py
# Downloading file: bdist_egg.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/bdist_egg.py
# Downloading file: install_egg_info.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/install_egg_info.py
# Downloading file: build_py.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/build_py.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/__init__.py
# Downloading file: develop.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/develop.py
# Downloading file: py36compat.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/py36compat.py
# Downloading file: sdist.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/sdist.py
# Downloading file: build_clib.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/build_clib.py
# Downloading file: egg_info.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/egg_info.py
# Downloading file: upload_docs.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/upload_docs.py
# Downloading file: dist_info.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/dist_info.py
# Downloading file: rotate.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/command/rotate.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/__init__.py
# Downloading file: msvc.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/msvc.py
# Downloading file: depends.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/depends.py
# Downloading file: script.tmpl -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/script.tmpl
# Downloading file: installer.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/installer.py
# Downloading file: gui-64.exe -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/gui-64.exe
# Downloading file: build_meta.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/build_meta.py
# Downloading file: monkey.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/monkey.py
# Downloading file: gui.exe -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/gui.exe
# Downloading file: archive_util.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/archive_util.py
# Downloading file: _imp.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_imp.py
# Downloading file: package_index.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/package_index.py
# Downloading file: gui-32.exe -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/gui-32.exe
# Downloading file: cli.exe -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/cli.exe
# Downloading file: cli-32.exe -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/cli-32.exe
# Downloading file: sandbox.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/sandbox.py
# Downloading file: glob.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/glob.py
# Downloading file: py34compat.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/py34compat.py
# Downloading file: version.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/version.py
# Downloading file: extension.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/extension.py
# Downloading file: errors.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/errors.py
# Downloading file: cli-64.exe -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/cli-64.exe
# Downloading file: dep_util.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/dep_util.py
# Downloading file: namespaces.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/namespaces.py
# Downloading file: wheel.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/wheel.py
# Downloading file: dist.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/dist.py
# Downloading file: script (dev).tmpl -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/script (dev).tmpl
# Downloading file: windows_support.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/windows_support.py
# Downloading file: config.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/config.py
# Downloading file: launch.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/launch.py
# Downloading file: _deprecation_warning.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/_deprecation_warning.py
# Downloading file: unicode_utils.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools/unicode_utils.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/tests
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/tests/data
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/tests/data/my-test-package-source
# Downloading file: setup.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/tests/data/my-test-package-source/setup.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/__init__.py
# Downloading file: requirements.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/requirements.py
# Downloading file: tags.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/tags.py
# Downloading file: _typing.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/_typing.py
# Downloading file: _compat.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/_compat.py
# Downloading file: version.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/version.py
# Downloading file: _structures.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/_structures.py
# Downloading file: specifiers.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/specifiers.py
# Downloading file: markers.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/markers.py
# Downloading file: __about__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/__about__.py
# Downloading file: utils.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/utils.py
# Downloading file: pyparsing.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/pyparsing.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/__init__.py
# Downloading file: appdirs.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/appdirs.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/extern
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/extern/__init__.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pkg_resources/__init__.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/_distutils_hack
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/_distutils_hack/__init__.py
# Downloading file: override.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/_distutils_hack/override.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/truststore
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/truststore/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/distro
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/distro/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/packaging
# Downloading file: LICENSE.BSD -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/packaging/LICENSE.BSD
# Downloading file: LICENSE.APACHE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/packaging/LICENSE.APACHE
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/packaging/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/pygments
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/pygments/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/dependency_groups
# Downloading file: LICENSE.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/dependency_groups/LICENSE.txt
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/idna
# Downloading file: LICENSE.md -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/idna/LICENSE.md
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/msgpack
# Downloading file: COPYING -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/msgpack/COPYING
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/cachecontrol
# Downloading file: LICENSE.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/cachecontrol/LICENSE.txt
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/distlib
# Downloading file: LICENSE.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/distlib/LICENSE.txt
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/rich
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/rich/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/tomli_w
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/tomli_w/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/platformdirs
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/platformdirs/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/resolvelib
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/resolvelib/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/pkg_resources
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/pkg_resources/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/requests
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/requests/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/tomli
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/tomli/LICENSE
# Downloading file: LICENSE-HEADER -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/tomli/LICENSE-HEADER
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/pyproject_hooks
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/pyproject_hooks/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/urllib3
# Downloading file: LICENSE.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/urllib3/LICENSE.txt
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/certifi
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/src/pip/_vendor/certifi/LICENSE
# Downloading file: AUTHORS.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/AUTHORS.txt
# Downloading file: LICENSE.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/licenses/LICENSE.txt
# Downloading file: WHEEL -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/WHEEL
# Downloading file: RECORD -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/RECORD
# Downloading file: top_level.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/top_level.txt
# Downloading file: REQUESTED -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/REQUESTED
# Downloading file: INSTALLER -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/INSTALLER
# Downloading file: METADATA -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/METADATA
# Downloading file: entry_points.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip-25.2.dist-info/entry_points.txt
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info
# Downloading file: REQUESTED -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info/REQUESTED
# Downloading file: top_level.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info/top_level.txt
# Downloading file: entry_points.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info/entry_points.txt
# Downloading file: RECORD -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info/RECORD
# Downloading file: METADATA -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info/METADATA
# Downloading file: WHEEL -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info/WHEEL
# Downloading file: INSTALLER -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info/INSTALLER
# Downloading file: LICENSE -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/setuptools-58.0.4.dist-info/LICENSE
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils
# Downloading file: retry.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/retry.py
# Downloading file: hashes.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/hashes.py
# Downloading file: urls.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/urls.py
# Downloading file: virtualenv.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/virtualenv.py
# Downloading file: misc.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/misc.py
# Downloading file: logging.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/logging.py
# Downloading file: wheel.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/wheel.py
# Downloading file: temp_dir.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/temp_dir.py
# Downloading file: glibc.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/glibc.py
# Downloading file: setuptools_build.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/setuptools_build.py
# Downloading file: subprocess.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/subprocess.py
# Downloading file: unpacking.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/unpacking.py
# Downloading file: packaging.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/packaging.py
# Downloading file: direct_url_helpers.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/direct_url_helpers.py
# Downloading file: entrypoints.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/entrypoints.py
# Downloading file: egg_link.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/egg_link.py
# Downloading file: _jaraco_text.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/_jaraco_text.py
# Downloading file: compatibility_tags.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/compatibility_tags.py
# Downloading file: filesystem.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/filesystem.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/__init__.py
# Downloading file: compat.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/compat.py
# Downloading file: deprecation.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/deprecation.py
# Downloading file: datetime.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/datetime.py
# Downloading file: appdirs.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/appdirs.py
# Downloading file: _log.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/_log.py
# Downloading file: filetypes.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/utils/filetypes.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network
# Downloading file: xmlrpc.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network/xmlrpc.py
# Downloading file: lazy_wheel.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network/lazy_wheel.py
# Downloading file: download.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network/download.py
# Downloading file: cache.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network/cache.py
# Downloading file: session.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network/session.py
# Downloading file: utils.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network/utils.py
# Downloading file: auth.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network/auth.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/network/__init__.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/req
# Downloading file: req_set.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/req/req_set.py
# Downloading file: req_install.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/req/req_install.py
# Downloading file: req_file.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/req/req_file.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/req/__init__.py
# Downloading file: constructors.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/req/constructors.py
# Downloading file: req_dependency_group.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/req/req_dependency_group.py
# Downloading file: req_uninstall.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/req/req_uninstall.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/__init__.py
# Downloading file: index.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/index.py
# Downloading file: direct_url.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/direct_url.py
# Downloading file: selection_prefs.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/selection_prefs.py
# Downloading file: scheme.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/scheme.py
# Downloading file: candidate.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/candidate.py
# Downloading file: installation_report.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/installation_report.py
# Downloading file: format_control.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/format_control.py
# Downloading file: search_scope.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/search_scope.py
# Downloading file: link.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/link.py
# Downloading file: wheel.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/wheel.py
# Downloading file: target_python.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/target_python.py
# Downloading file: pylock.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/models/pylock.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli
# Downloading file: status_codes.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/status_codes.py
# Downloading file: autocompletion.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/autocompletion.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/__init__.py
# Downloading file: command_context.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/command_context.py
# Downloading file: base_command.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/base_command.py
# Downloading file: main_parser.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/main_parser.py
# Downloading file: req_command.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/req_command.py
# Downloading file: index_command.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/index_command.py
# Downloading file: spinners.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/spinners.py
# Downloading file: progress_bars.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/progress_bars.py
# Downloading file: parser.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/parser.py
# Downloading file: cmdoptions.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/cmdoptions.py
# Downloading file: main.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/cli/main.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/operations
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/operations/install
# Downloading file: wheel.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/operations/install/wheel.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_internal/operations/install/__init__.py
# ...
# Downloading file: json.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/json.py
# Downloading file: file_proxy.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/file_proxy.py
# Downloading file: color.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/color.py
# Downloading file: _fileno.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/_fileno.py
# Downloading file: _loop.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/_loop.py
# Downloading file: _emoji_codes.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/_emoji_codes.py
# Downloading file: status.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/status.py
# Downloading file: live_render.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/live_render.py
# Downloading file: logging.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/logging.py
# Downloading file: padding.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/padding.py
# Downloading file: bar.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/bar.py
# Downloading file: tree.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/tree.py
# Downloading file: _windows.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/_windows.py
# Downloading file: theme.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/theme.py
# Downloading file: protocol.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/protocol.py
# Downloading file: _palettes.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/_palettes.py
# Downloading file: pretty.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/pretty.py
# Downloading file: _windows_renderer.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/_windows_renderer.py
# Downloading file: _pick.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/_pick.py
# Downloading file: control.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/rich/control.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/pkg_resources
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/pkg_resources/__init__.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util
# Downloading file: ssltransport.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/ssltransport.py
# Downloading file: connection.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/connection.py
# Downloading file: wait.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/wait.py
# Downloading file: response.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/response.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/__init__.py
# Downloading file: timeout.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/timeout.py
# Downloading file: retry.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/retry.py
# Downloading file: queue.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/queue.py
# Downloading file: request.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/request.py
# Downloading file: url.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/url.py
# Downloading file: proxy.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/proxy.py
# Downloading file: ssl_match_hostname.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/ssl_match_hostname.py
# Downloading file: ssl_.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/ssl_.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/backports
# Downloading file: makefile.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/backports/makefile.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/backports/__init__.py
# Downloading file: weakref_finalize.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/backports/weakref_finalize.py
# Downloading file: six.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/six.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/__init__.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/_securetransport
# Downloading file: low_level.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/_securetransport/low_level.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/_securetransport/__init__.py
# Downloading file: bindings.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/_securetransport/bindings.py
# Downloading file: _appengine_environ.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/_appengine_environ.py
# Downloading file: appengine.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/appengine.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/__init__.py
# Downloading file: pyopenssl.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/pyopenssl.py
# Downloading file: socks.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/socks.py
# Downloading file: securetransport.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/securetransport.py
# Downloading file: ntlmpool.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/ntlmpool.py
# Downloading file: _version.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/_version.py
# Downloading file: filepost.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/filepost.py
# Downloading file: _collections.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/_collections.py
# Downloading file: response.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py
# Downloading file: fields.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/fields.py
# Downloading file: request.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/request.py
# Downloading file: exceptions.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/exceptions.py
# Downloading file: poolmanager.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/poolmanager.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/__init__.py
# Downloading file: connection.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/connection.py
# Downloading file: connectionpool.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/connectionpool.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/__init__.py
# Downloading file: android.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/android.py
# Downloading file: __main__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/__main__.py
# Downloading file: api.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/api.py
# Downloading file: version.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/version.py
# Downloading file: unix.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/unix.py
# Downloading file: macos.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/macos.py
# Downloading file: windows.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/windows.py
# Downloading file: py.typed -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/py.typed
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/tomli_w
# Downloading file: py.typed -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/tomli_w/py.typed
# Downloading file: _writer.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/tomli_w/_writer.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/tomli_w/__init__.py
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers
# Downloading file: criterion.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers/criterion.py
# Downloading file: exceptions.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers/exceptions.py
# Downloading file: abstract.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers/abstract.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers/__init__.py
# Downloading file: resolution.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers/resolution.py
# Downloading file: reporters.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/reporters.py
# Downloading file: structs.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/structs.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/__init__.py
# Downloading file: providers.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/providers.py
# Downloading file: py.typed -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/py.typed
# Downloading file: vendor.txt -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/vendor.txt
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/_vendor/__init__.py
# Downloading file: __pip-runner__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/__pip-runner__.py
# Downloading file: __init__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/__init__.py
# Downloading file: __main__.py -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/__main__.py
# Downloading file: py.typed -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/pip/py.typed
# Downloading file: distutils-precedence.pth -> /content/RAG-Based-AI-Teaching-Assistant/.venv/lib/python3.9/site-packages/distutils-precedence.pth
# Creating folder: /content/RAG-Based-AI-Teaching-Assistant/.venv/bin
# Downloading file: pip3.9 -> /content/RAG-Based-AI-Teaching-Assistant/.venv/bin/pip3.9
# Downloading file: pip -> /content/RAG-Based-AI-Teaching-Assistant/.venv/bin/pip
# Downloading file: pip3 -> /content/RAG-Based-AI-Teaching-Assistant/.venv/bin/pip3
# Downloading file: activate.fish -> /content/RAG-Based-AI-Teaching-Assistant/.venv/bin/activate.fish
# Downloading file: activate -> /content/RAG-Based-AI-Teaching-Assistant/.venv/bin/activate
# Downloading file: Activate.ps1 -> /content/RAG-Based-AI-Teaching-Assistant/.venv/bin/Activate.ps1
# Downloading file: activate.csh -> /content/RAG-Based-AI-Teaching-Assistant/.venv/bin/activate.csh
# Downloading file: pyvenv.cfg -> /content/RAG-Based-AI-Teaching-Assistant/.venv/pyvenv.cfg
# Downloading file: mp3_to_json.py -> /content/RAG-Based-AI-Teaching-Assistant/mp3_to_json.py
# Downloading file: process_incoming.py -> /content/RAG-Based-AI-Teaching-Assistant/process_incoming.py
# Downloading file: video_to_mp3.py -> /content/RAG-Based-AI-Teaching-Assistant/video_to_mp3.py
# Downloading file: preprocess_json.py -> /content/RAG-Based-AI-Teaching-Assistant/preprocess_json.py
# Downloading file: README.md -> /content/RAG-Based-AI-Teaching-Assistant/README.md
# Using PROJECT_DIR = /content/RAG-Based-AI-Teaching-Assistant
# Current working directory:
# /content/RAG-Based-AI-Teaching-Assistant
#
# Files in project directory (top-level):
# total 40
# drwxr-xr-x 4 root root 4096 Nov  1 08:31 .
# drwxr-xr-x 1 root root 4096 Nov  1 08:18 ..
# drwxr-xr-x 7 root root 4096 Nov  1 08:19 .git
# -rw-r--r-- 1 root root  925 Nov  1 08:31 mp3_to_json.py
# -rw-r--r-- 1 root root 1045 Nov  1 08:31 preprocess_json.py
# -rw-r--r-- 1 root root 2315 Nov  1 08:31 process_incoming.py
# -rw-r--r-- 1 root root 2992 Nov  1 08:31 README.md
# drwxr-xr-x 4 root root 4096 Nov  1 08:31 .venv
# -rw-r--r-- 1 root root  345 Nov  1 08:31 video_to_mp3.py

# %% [markdown]
# **📁 Cell 3 Description:**
#
# This cell ensures that the required project directories — videos, audios, and jsons — exist in the current workspace. It then lists the contents of these folders along with the root directory, helping you verify that all necessary files are correctly organized before proceeding with audio extraction or transcription steps.

# %%
# Cell 3: ensure expected folders exist and list key files
import os
os.makedirs("videos", exist_ok=True)
os.makedirs("audios", exist_ok=True)
os.makedirs("jsons", exist_ok=True)

print("videos folder listing:")
# !ls -la videos || true
print("\naudios folder listing:")
# !ls -la audios || true
print("\nroot files:")
# !ls -la
# Out:
# videos folder listing:
# total 8
# drwxr-xr-x 2 root root 4096 Nov  1 08:32 .
# drwxr-xr-x 7 root root 4096 Nov  1 08:32 ..
#
# audios folder listing:
# total 8
# drwxr-xr-x 2 root root 4096 Nov  1 08:32 .
# drwxr-xr-x 7 root root 4096 Nov  1 08:32 ..
#
# root files:
# total 52
# drwxr-xr-x 7 root root 4096 Nov  1 08:32 .
# drwxr-xr-x 1 root root 4096 Nov  1 08:18 ..
# drwxr-xr-x 2 root root 4096 Nov  1 08:32 audios
# drwxr-xr-x 7 root root 4096 Nov  1 08:19 .git
# drwxr-xr-x 2 root root 4096 Nov  1 08:32 jsons
# -rw-r--r-- 1 root root  925 Nov  1 08:31 mp3_to_json.py
# -rw-r--r-- 1 root root 1045 Nov  1 08:31 preprocess_json.py
# -rw-r--r-- 1 root root 2315 Nov  1 08:31 process_incoming.py
# -rw-r--r-- 1 root root 2992 Nov  1 08:31 README.md
# drwxr-xr-x 4 root root 4096 Nov  1 08:31 .venv
# drwxr-xr-x 2 root root 4096 Nov  1 08:32 videos
# -rw-r--r-- 1 root root  345 Nov  1 08:31 video_to_mp3.py

# %% [markdown]
# **🎥 Cell 4 Description:**
#
# This cell automatically converts all video files in the videos/ folder into MP3 audio files using FFmpeg. It ensures a clean output by handling filenames safely and saving the resulting audio files into the audios/ directory. This step is essential for preparing your video lectures or tutorials for offline transcription using the Vosk speech recognition model in later cells.

# %%
# Cell 4: Convert all videos in videos/ -> audios/ using ffmpeg
import os, shlex, subprocess, pathlib

VIDEO_DIR = "videos"
AUDIO_DIR = "audios"
os.makedirs(AUDIO_DIR, exist_ok=True)

def to_mp3(vpath, outdir=AUDIO_DIR):
    p = pathlib.Path(vpath)
    safe_name = p.stem.replace(" ", "_").replace("[","").replace("]","").replace("#","")
    out = os.path.join(outdir, f"{safe_name}.mp3")
    cmd = f'ffmpeg -y -i {shlex.quote(str(vpath))} -vn -acodec libmp3lame -q:a 2 {shlex.quote(out)}'
    print("Running:", cmd)
    subprocess.run(cmd, shell=True, check=True)
    return out

videos = [os.path.join(VIDEO_DIR, f) for f in os.listdir(VIDEO_DIR) if not f.startswith(".")]
if len(videos) == 0:
    print("No videos found in", VIDEO_DIR, "- add mp4 files there (or upload).")
else:
    for v in videos:
        try:
            mp3 = to_mp3(v)
            print("Wrote:", mp3)
        except Exception as e:
            print("Error converting", v, e)
# Out:
# Running: ffmpeg -y -i videos/Lecture_1_Black_Hole.mp4 -vn -acodec libmp3lame -q:a 2 audios/Lecture_1_Black_Hole.mp3
# Wrote: audios/Lecture_1_Black_Hole.mp3

# %% [markdown]
# **🗣️ Cell 5 Description:**
#
# This cell performs automatic transcription of all .mp3 files in the audios/ folder using the Vosk offline speech recognition model.
# It first ensures the Vosk model is available (and downloads it if missing), then converts each MP3 to a 16 kHz mono WAV (the required input format). The audio is processed in chunks, and the recognized text is stored in structured JSON files under the jsons/ directory.
# Each JSON file contains the full transcript, word-level timing data, and model details — forming the foundation for later embedding or retrieval-based analysis.

# %%
# ✅ Cell 5: Transcribe all mp3 files in audios/ → jsons/ using Vosk
import os, json, pathlib, subprocess, shlex
from pathlib import Path
from tqdm import tqdm

# Folders
AUDIO_DIR = "audios"
JSON_DIR = "jsons"
MODEL_DIR = "vosk_model"

os.makedirs(JSON_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)

# Attempt to download a small English model if not present
MODEL_PATH = Path(MODEL_DIR)
if not any(MODEL_PATH.iterdir()):
    print("No Vosk model found, downloading small English model (if internet available)...")
    try:
        model_url = "https://alphacephei.com/vosk/models/vosk-model-small-en-us-0.15.zip"
        zip_path = "/tmp/vosk_model.zip"
        subprocess.run(f"wget -q -O {zip_path} {model_url}", shell=True, check=True)
        subprocess.run(f"unzip -q {zip_path} -d {MODEL_DIR}", shell=True, check=True)
        # Move contents up one level if nested
        inner = next(Path(MODEL_DIR).glob("vosk-model-*"), None)
        if inner:
            for f in inner.iterdir():
                subprocess.run(f"mv {f} {MODEL_DIR}/", shell=True)
            subprocess.run(f"rm -rf {inner}", shell=True)
        print("✅ Model downloaded and extracted to", MODEL_DIR)
    except Exception as e:
        print("⚠️ Could not download Vosk model automatically:", e)
        print("→ Please manually upload a model folder into", MODEL_DIR)

# Import vosk
from vosk import Model, KaldiRecognizer
import wave

# Load model
print("Loading Vosk model from:", MODEL_DIR)
model = Model(MODEL_DIR)

# Helper: convert mp3 → 16 kHz mono WAV (Vosk requires WAV)
def mp3_to_wav_16k(src_mp3, dst_wav):
    cmd = f'ffmpeg -y -i {shlex.quote(src_mp3)} -ac 1 -ar 16000 -vn {shlex.quote(dst_wav)}'
    subprocess.run(cmd, shell=True, check=True)

# Process each MP3
mp3_files = sorted(Path(AUDIO_DIR).glob("*.mp3"))
if not mp3_files:
    print("⚠️ No mp3 files found in", AUDIO_DIR)
else:
    for mp3 in tqdm(mp3_files, desc="Transcribing MP3s"):
        try:
            wav_path = Path("/tmp") / (mp3.stem + "_16k.wav")
            mp3_to_wav_16k(str(mp3), str(wav_path))

            wf = wave.open(str(wav_path), "rb")
            rec = KaldiRecognizer(model, 16000)
            rec.SetWords(True)

            results = []
            while True:
                data = wf.readframes(4000)
                if len(data) == 0:
                    break
                if rec.AcceptWaveform(data):
                    part = json.loads(rec.Result())
                    results.append(part)
            results.append(json.loads(rec.FinalResult()))
            wf.close()

            text = " ".join([r.get("text", "") for r in results]).strip()
            out = {
                "file": mp3.name,
                "text": text,
                "segments": results,
                "model": "vosk-small-en-us-0.15"
            }

            out_path = Path(JSON_DIR) / (mp3.stem + ".json")
            with open(out_path, "w", encoding="utf-8") as fh:
                json.dump(out, fh, ensure_ascii=False, indent=2)
            print("✅ Saved transcript:", out_path)
        except Exception as e:
            print("❌ Error transcribing", mp3, ":", e)
# Out:
# No Vosk model found, downloading small English model (if internet available)...
# ✅ Model downloaded and extracted to vosk_model
# Loading Vosk model from: vosk_model
# Transcribing MP3s: 100%|██████████| 1/1 [00:02<00:00,  2.50s/it]
# ✅ Saved transcript: jsons/Lecture_1_Black_Hole.json

# %% [markdown]
# **🧹Cell 6 Description:**
#
# This cell performs **basic preprocessing and cleanup** of the raw transcription JSON files generated by Vosk.
# It reads each JSON file from the `jsons/` directory, removes unnecessary metadata, and keeps only the essential fields — the filename, transcribed text, segments, and language (if available).
# The cleaned and lightweight versions are then saved into a new folder, `jsons/clean`, making them ready for **faster downstream processing**, such as text embedding or retrieval-based question answering.

# %%
# Cell 6: Minimal preprocessing fallback - creates cleaned JSONs in jsons/clean_
import os, json, glob
from pathlib import Path

INPUT_DIR = "jsons"
OUT_DIR = "jsons/clean"
os.makedirs(OUT_DIR, exist_ok=True)

for f in Path(INPUT_DIR).glob("*.json"):
    try:
        j = json.load(open(f, "r", encoding="utf-8"))
        cleaned = {
            "file": f.name,
            "text": j.get("text", ""),
            "segments": j.get("segments", []),
            "language": j.get("language", "")
        }
        out = Path(OUT_DIR) / f.name
        json.dump(cleaned, open(out, "w", encoding="utf-8"), ensure_ascii=False, indent=2)
        print("Cleaned ->", out)
    except Exception as e:
        print("Skip", f, e)
# Out:
# Cleaned -> jsons/clean/Lecture_1_Black_Hole.json

# %% [markdown]
# 🧬 **Cell 7 Description:**
#
# This cell builds (or updates) your **embeddings dataset** from the cleaned transcripts in `jsons/clean`. It assembles a DataFrame of text chunks, **reuses any existing embeddings** from `embeddings.joblib`, computes only the **missing vectors** using `SentenceTransformer` (`all-MiniLM-L6-v2`), saves the result back to `embeddings.joblib`, and exposes it as `embeddings_df` for downstream RAG queries.

# %%
# Cell 7 - Ensure embeddings.joblib exists (create from jsons/clean if missing)
# Run this cell in the project root where jsons/clean and your scripts live.

# 0) Install dependencies (Colab-friendly). Comment out if already installed.
# !pip install -q sentence-transformers joblib pandas tqdm

# --- Begin Python logic ---
import os, glob, json, joblib, math
import pandas as pd
from sentence_transformers import SentenceTransformer
from tqdm.auto import tqdm

EMB_PATH = "embeddings.joblib"
CLEAN_JSON_DIR = "jsons/clean"   # change if your cleaned JSONs are elsewhere
MODEL_NAME = "all-MiniLM-L6-v2"  # small and fast; change if desired
BATCH_SIZE = 64                  # memory vs speed tradeoff

def load_json_chunks(jpath):
    """Return list of dicts with at least 'text' (and optionally start/end)."""
    with open(jpath, "r", encoding="utf-8") as f:
        data = json.load(f)
    # Common structures: list of chunks OR dict with 'chunks' OR dict with 'segments'/'results'
    if isinstance(data, list):
        chunks = data
    elif isinstance(data, dict) and "chunks" in data and isinstance(data["chunks"], list):
        chunks = data["chunks"]
    elif isinstance(data, dict) and ("segments" in data or "results" in data):
        chunks = data.get("segments", []) or data.get("results", [])
    else:
        # fallback: treat top-level dict as a single chunk if it has 'text' or 'transcript'
        if isinstance(data, dict) and ("text" in data or "transcript" in data):
            chunks = [data]
        else:
            chunks = []
    # Normalize each chunk to a dict with text/start/end
    out = []
    for c in chunks:
        if not isinstance(c, dict):
            continue
        text = c.get("text") or c.get("transcript") or ""
        text = text.strip()
        if not text:
            continue
        start = c.get("start") or c.get("start_time") or c.get("start_sec") or None
        end   = c.get("end")   or c.get("end_time")   or c.get("end_sec")   or None
        out.append({"text": text, "start": start, "end": end})
    return out

def build_dataframe_from_jsons(json_dir):
    files = sorted(glob.glob(os.path.join(json_dir, "*.json")))
    if not files:
        raise FileNotFoundError(f"No JSON files found in {json_dir}. Check path.")
    rows = []
    for jf in files:
        chunks = load_json_chunks(jf)
        if not chunks:
            # If load_json_chunks returned nothing, attempt simple fallback
            try:
                with open(jf, "r", encoding="utf-8") as f:
                    raw = f.read().strip()
                    if raw:
                        rows.append({"file": os.path.basename(jf), "text": raw, "start": None, "end": None})
            except Exception:
                pass
            continue
        for c in chunks:
            rows.append({
                "file": os.path.basename(jf),
                "text": c["text"],
                "start": c["start"],
                "end": c["end"]
            })
    df = pd.DataFrame(rows)
    if df.empty:
        raise RuntimeError("No transcript text extracted from JSONs.")
    df = df.reset_index(drop=True)
    df["id"] = df.index.astype(str)
    return df

# 1) If embeddings.joblib exists, load it and try to preserve embeddings
if os.path.exists(EMB_PATH):
    try:
        print("Loading existing", EMB_PATH)
        existing = joblib.load(EMB_PATH)
        if not isinstance(existing, pd.DataFrame):
            print("Warning: existing embeddings.joblib not a DataFrame — will overwrite.")
            existing = None
    except Exception as e:
        print("Failed to load existing embeddings.joblib:", e)
        existing = None
else:
    existing = None

# 2) Build dataframe from cleaned jsons
print("Building transcript DataFrame from JSONs in:", CLEAN_JSON_DIR)
df = build_dataframe_from_jsons(CLEAN_JSON_DIR)

# 3) If existing DF present and has 'id' and 'embedding', merge to keep embeddings
if existing is not None and "id" in existing.columns:
    # Align by 'id' if possible, otherwise fallback to merging by file+text
    if set(existing["id"].astype(str)).issuperset(set(df["id"].astype(str))):
        # simple replacement: take embeddings from existing where id matches
        existing_idxed = existing.set_index(existing["id"].astype(str))
        df = df.set_index(df["id"].astype(str))
        df["embedding"] = existing_idxed["embedding"]
        df = df.reset_index(drop=True)
        # reassign id as string index
        df["id"] = df.index.astype(str)
        print("Merged existing embeddings by id.")
    else:
        # fallback: merge on file+text (slower but robust)
        merged = df.merge(existing[["file","text","embedding"]], on=["file","text"], how="left")
        df = merged.rename(columns={"embedding": "embedding"}).copy()
        df["id"] = df.index.astype(str)
        print("Merged existing embeddings by file+text where possible.")
else:
    # ensure embedding column exists
    df["embedding"] = None

# 4) Find which rows need embeddings
missing_mask = df["embedding"].isna() | df["embedding"].apply(lambda x: x is None)
to_compute_texts = df.loc[missing_mask, "text"].astype(str).tolist()
print(f"Total rows: {len(df)} | Missing embeddings: {len(to_compute_texts)}")

# 5) Compute embeddings if needed
if len(to_compute_texts) > 0:
    print("Loading SBERT model:", MODEL_NAME)
    model = SentenceTransformer(MODEL_NAME)
    # We'll compute embeddings in batches to avoid memory spikes
    n = len(to_compute_texts)
    batches = math.ceil(n / BATCH_SIZE)
    embeddings = []
    for i in tqdm(range(batches), desc="embedding batches"):
        start = i * BATCH_SIZE
        end = min((i+1) * BATCH_SIZE, n)
        batch_texts = to_compute_texts[start:end]
        emb_batch = model.encode(batch_texts, show_progress_bar=False, convert_to_numpy=True, batch_size=BATCH_SIZE)
        embeddings.append(emb_batch)
    import numpy as np
    embeddings = np.vstack(embeddings)
    # Put embeddings back into df
    idxs = df.loc[missing_mask].index.tolist()
    if len(idxs) != embeddings.shape[0]:
        raise RuntimeError("Mismatch between indices to fill and number of embeddings computed.")
    for i, idx in enumerate(idxs):
        df.at[idx, "embedding"] = embeddings[i].tolist()
    # Save to joblib
    joblib.dump(df, EMB_PATH)
    print("✅ Saved embeddings.joblib with", len(df), "rows.")
else:
    print("No missing embeddings. Using existing embeddings.joblib as-is.")

# 6) Quick sanity checks and expose df as embeddings_df to be used by downstream cells
embeddings_df = df  # name downstream code can use
print("embeddings_df ready. Sample columns:", embeddings_df.columns.tolist())
if embeddings_df.loc[embeddings_df["embedding"].notna()].shape[0] > 0:
    sample_emb = embeddings_df.loc[embeddings_df["embedding"].notna(), "embedding"].iloc[0]
    print("Sample embedding length:", len(sample_emb))
else:
    print("Warning: no embeddings present after run.")
# Out:
# Building transcript DataFrame from JSONs in: jsons/clean
# Total rows: 2 | Missing embeddings: 2
# Loading SBERT model: all-MiniLM-L6-v2
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# embedding batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Saved embeddings.joblib with 2 rows.
# embeddings_df ready. Sample columns: ['file', 'text', 'start', 'end', 'id', 'embedding']
# Sample embedding length: 384

# %%
import os
os.environ["GROQ_API_KEY"] = "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"

# %% [markdown]
# 🤖 **Cell 8 Description:**
#
# This cell enables **Retrieval-Augmented Generation (RAG)** using either **Groq** or **Gemini** as the language model backend.
# It loads the precomputed **embeddings** into a **FAISS** index for fast similarity search, retrieves the most relevant text chunks for each query, and then feeds them into a powerful LLM (Groq or Gemini) to generate **context-aware answers**.
# If neither API key is set, it prompts you to configure one. Once active, you can **interactively ask questions**, and the assistant will respond using only the provided course or lecture content — ideal for creating an **AI-powered teaching assistant** experience.

# %%
# ===========================
# ✅ CELL 8 — RAG with Groq or Gemini (auto-pick model)
# ===========================
# !pip -q install faiss-cpu sentence-transformers joblib groq google-generativeai

import os, numpy as np, joblib, faiss, sys, traceback
from sentence_transformers import SentenceTransformer

from google.colab import userdata
userdata.get('RAG-API')

# -----------------------------
# 1) Load embeddings + index
# -----------------------------
embeddings_df = joblib.load("embeddings.joblib")
emb_matrix = np.vstack(embeddings_df["embedding"].values).astype("float32")
texts = embeddings_df["text"].tolist()

index = faiss.IndexFlatL2(emb_matrix.shape[1])
index.add(emb_matrix)
print(f"✅ Loaded {len(texts)} chunks into FAISS.")

embedder = SentenceTransformer("all-MiniLM-L6-v2")

def retrieve_context(query, top_k=4):
    q = embedder.encode([query], convert_to_numpy=True).astype("float32")
    _, idx = index.search(q, top_k)
    return "\n\n".join([f"[{r+1}] {texts[i]}" for r, i in enumerate(idx[0])])

# -----------------------------
# 2) Pick provider (GROQ/GEMINI)
# -----------------------------
PROVIDER = "GROQ" if os.getenv("GROQ_API_KEY") else ("GEMINI" if os.getenv("GEMINI_API_KEY") else None)
if not PROVIDER:
    raise RuntimeError(
        "No provider configured. Set one of:\n"
        "  os.environ['GROQ_API_KEY']   = '...'\n"
        "  os.environ['GEMINI_API_KEY'] = '...'\n"
        "Then re-run this cell."
    )

SYSTEM_PROMPT = (
    "You are a precise teaching assistant. Use ONLY the provided context. "
    "If the answer isn't in the context, say you don't know briefly."
)

# -----------------------------
# 3) Provider-specific setup
# -----------------------------
if PROVIDER == "GROQ":
    from groq import Groq
    groq_client = Groq(api_key=os.environ["GROQ_API_KEY"])

    # List models available to this key and auto-pick a good one
    try:
        available_models = sorted([m.id for m in groq_client.models.list().data])
    except Exception:
        print("⚠️ Could not list Groq models. Trying known names.")
        available_models = []

    print("🔎 Groq models available:\n", "\n ".join(available_models) or "(listing failed)")

    PREFERRED = [
        # common currently-supported ids (adjusts over time)
        "llama-3.1-70b-specdec",
        "llama-3.1-8b-instant",
        "mixtral-8x7b-32768",
        "gemma2-9b-it",
        # fallbacks some accounts expose
        "llama3-70b-8192",
        "llama3-8b-8192",
    ]
    MODEL = next((m for m in PREFERRED if (not available_models or m in available_models)), None)
    if not MODEL:
        raise RuntimeError(
            "No preferred Groq models found for your key. Enable one in Groq console, "
            "or replace PREFERRED with a model id you do have."
        )

    print(f"✅ Using Groq model: {MODEL}")

    def generate_answer(query, context):
        prompt = f"{SYSTEM_PROMPT}\n\nCONTEXT:\n{context}\n\nQUESTION:\n{query}\n\nAnswer:"
        try:
            resp = groq_client.chat.completions.create(
                model=MODEL,
                messages=[{"role": "user", "content": prompt}],
                temperature=0.2,
                max_tokens=512,
            )
            return resp.choices[0].message.content.strip()
        except Exception as e:
            return f"[Generation error: {e}]"

elif PROVIDER == "GEMINI":
    import google.generativeai as genai
    genai.configure(api_key=os.environ["GEMINI_API_KEY"])
    model = genai.GenerativeModel("gemini-1.5-flash")

    def generate_answer(query, context):
        prompt = f"{SYSTEM_PROMPT}\n\nCONTEXT:\n{context}\n\nQUESTION:\n{query}\n\nAnswer:"
        try:
            resp = model.generate_content(prompt)
            return (resp.text or "").strip()
        except Exception as e:
            return f"[Generation error: {e}]"

# -----------------------------
# 4) Interactive QA
# -----------------------------
def ask_question():
    print(f"🔌 Provider: {PROVIDER}\nType 'exit' to quit.")
    while True:
        q = input("\n❓ Your question: ").strip()
        if q.lower() in ("exit","quit"):
            print("👋 Bye!"); break
        ctx = retrieve_context(q, top_k=4)
        print("\n🔎 Retrieved Context:\n", (ctx[:800] + ("..." if len(ctx) > 800 else "")))
        ans = generate_answer(q, ctx)
        print("\n💬 Answer:\n", ans)

ask_question()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 59.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 6.9 MB/s eta 0:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3386079141.py in <cell line: 0>()
#       5
#       6 import os, numpy as np, joblib, faiss, sys, traceback
# ----> 7 from sentence_transformers import SentenceTransformer
#       8
#       9 from google.colab import userdata
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/__init__.py in <module>
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/cross_encoder/__init__.py in <module>
#       1 from __future__ import annotations
#       2
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py in <module>
#      14 from torch import nn
#      15 from tqdm.autonotebook import trange
# ---> 16 from transformers import (
#      17     AutoConfig,
#      18     AutoModelForSequenceClassification,
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    2315         elif name in self._class_to_module:
#    2316             try:
# -> 2317                 module = self._get_module(self._class_to_module[name])
#    2318                 value = getattr(module, name)
#    2319             except (ModuleNotFoundError, RuntimeError) as e:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    2343     def _get_module(self, module_name: str):
#    2344         try:
# -> 2345             return importlib.import_module("." + module_name, self.__name__)
#    2346         except Exception as e:
#    2347             raise e
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/modeling_auto.py in <module>
#      21
#      22 from ...utils import logging
# ---> 23 from .auto_factory import (
#      24     _BaseAutoBackboneClass,
#      25     _BaseAutoModelClass,
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in <module>
#      41
#      42 if is_torch_available():
# ---> 43     from ...generation import GenerationMixin
#      44
#      45
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    2315         elif name in self._class_to_module:
#    2316             try:
# -> 2317                 module = self._get_module(self._class_to_module[name])
#    2318                 value = getattr(module, name)
#    2319             except (ModuleNotFoundError, RuntimeError) as e:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    2343     def _get_module(self, module_name: str):
#    2344         try:
# -> 2345             return importlib.import_module("." + module_name, self.__name__)
#    2346         except Exception as e:
#    2347             raise e
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in <module>
#      41 from ..integrations.deepspeed import is_deepspeed_zero3_enabled
#      42 from ..integrations.fsdp import is_fsdp_managed_module
# ---> 43 from ..masking_utils import create_masks_for_generate
#      44 from ..pytorch_utils import isin_mps_friendly
#      45 from ..tokenization_utils import ExtensionsTrie
#
# /usr/local/lib/python3.12/dist-packages/transformers/masking_utils.py in <module>
#      38
#      39 if _is_torch_greater_or_equal_than_2_6:
# ---> 40     from torch._dynamo._trace_wrapped_higher_order_op import TransformGetItemToIndex
#      41
#      42
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/__init__.py in <module>
#      11 import torch
#      12
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#      15 from .callback import callback_handler, on_compile_end, on_compile_start
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/convert_frame.py in <module>
#      51 from torch._dynamo.callback import CallbackTrigger
#      52 from torch._dynamo.distributed import get_compile_pg
# ---> 53 from torch._dynamo.symbolic_convert import TensorifyState
#      54 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      55 from torch._logging import structured
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/symbolic_convert.py in <module>
#      56 from torch.utils._functools import cache_method
#      57
# ---> 58 from . import (
#      59     config,
#      60     exc,
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/trace_rules.py in <module>
#      54 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      55 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 56 from .variables import (
#      57     BuiltinVariable,
#      58     FunctionalCallVariable,
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/__init__.py in <module>
#      17 """
#      18
# ---> 19 from .base import VariableTracker
#      20 from .builtin import BuiltinVariable
#      21 from .constant import ConstantVariable, EnumVariable
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/base.py in <module>
#     640
#     641
# --> 642 from . import builder
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/builder.py in <module>
#      91     process_automatic_dynamic,
#      92 )
# ---> 93 from ..side_effects import SideEffects
#      94 from ..source import (
#      95     AttrProxySource,
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/side_effects.py in <module>
#      42     create_instruction,
#      43 )
# ---> 44 from .codegen import PyCodegen
#      45 from .exc import SideEffectsError, unimplemented_v2
#      46 from .source import GlobalSource, LocalCellSource, LocalSource, Source
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/codegen.py in <module>
#      45     LocalGeneratorObjectVariable,
#      46 )
# ---> 47 from .variables.nn_module import NNModuleVariable
#      48 from .variables.tensor import (
#      49     NumpyNdarrayVariable,
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/nn_module.py in <module>
#      68 from .base import typestr, ValueMutationNew, VariableTracker
#      69 from .functions import invoke_and_store_as_constant
# ---> 70 from .lazy import LazyVariableTracker
#      71 from .lists import SliceVariable
#      72 from .user_defined import UserDefinedObjectVariable
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/lazy.py in <module>
#       7 from ..utils import is_function_or_wrapper
#       8 from .base import VariableTracker
# ----> 9 from .tensor import SymNodeVariable
#      10
#      11
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/tensor.py in <module>
#      32 import torch.fx
#      33 import torch.random
# ---> 34 from torch._dynamo import compiled_autograd
#      35 from torch._subclasses.meta_utils import is_sparse_any
#      36 from torch.fx.experimental.symbolic_shapes import (
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/compiled_autograd.py in <module>
#      41     set_locals_to_steal,
#      42 )
# ---> 43 from torch._functorch._aot_autograd.runtime_wrappers import (
#      44     AutogradLazyBackwardCompileInfo,
#      45     CachedAutogradLazyBackwardCompileInfo,
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py in <module>
#      39
#      40 from .. import config
# ---> 41 from .collect_metadata_analysis import run_functionalized_fw_and_collect_metadata
#      42 from .functional_utils import gen_alias_from_base
#      43 from .input_output_analysis import (
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/collect_metadata_analysis.py in <module>
#      39     was_inductor_storage_resized,
#      40 )
# ---> 41 from .schemas import (
#      42     FunctionalTensorMetadataEq,
#      43     InputAliasInfo,
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/schemas.py in <module>
#     203
#     204
# --> 205 @dataclass
#     206 class SubclassCreationMeta:
#     207     """
#
# /usr/lib/python3.12/dataclasses.py in dataclass(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#    1273
#    1274     # We're called as @dataclass without parens.
# -> 1275     return wrap(cls)
#    1276
#    1277
#
# /usr/lib/python3.12/dataclasses.py in wrap(cls)
#    1263
#    1264     def wrap(cls):
# -> 1265         return _process_class(cls, init, repr, eq, order, unsafe_hash,
#    1266                               frozen, match_args, kw_only, slots,
#    1267                               weakref_slot)
#
# /usr/lib/python3.12/dataclasses.py in _process_class(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#    1061
#    1062         _set_new_attribute(cls, '__init__',
# -> 1063                            _init_fn(all_init_fields,
#    1064                                     std_init_fields,
#    1065                                     kw_only_init_fields,
#
# /usr/lib/python3.12/dataclasses.py in _init_fn(fields, std_fields, kw_only_fields, frozen, has_post_init, self_name, globals, slots)
#     617         _init_params += ['*']
#     618         _init_params += [_init_param(f) for f in kw_only_fields]
# --> 619     return _create_fn('__init__',
#     620                       [self_name] + _init_params,
#     621                       body_lines,
#
# /usr/lib/python3.12/dataclasses.py in _create_fn(name, args, body, globals, locals, return_type)
#     471     txt = f"def __create_fn__({local_vars}):\n{txt}\n return {name}"
#     472     ns = {}
# --> 473     exec(txt, globals, ns)
#     474     return ns['__create_fn__'](**locals)
#     475
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/schemas.py in <module>
#
# KeyboardInterrupt:

# %% [markdown]
# # **🧩 Project Summary**
#
# **Project Title: 🧠 RAG-Based Teaching AI Assistant (Offline Vosk + Embeddings + RAG Integration)**
#
# This project builds a Retrieval-Augmented Generation (RAG) pipeline that converts video lectures into structured, searchable text and enables an AI-powered question-answering system — all while maintaining offline speech recognition capabilities using Vosk.
#
# The system automatically:
#
# Imports your teaching project folder directly from Google Drive.
#
# Converts all uploaded video lectures (.mp4) into audio files (.mp3) using ffmpeg.
#
# Transcribes those audios offline using the Vosk speech recognition model.
#
# Cleans and structures the resulting text data into lightweight JSON files.
#
# Creates semantic embeddings using SentenceTransformers for context retrieval.
#
# Builds a FAISS vector index for efficient similarity search.
#
# Integrates with Groq or Gemini LLMs for natural, context-aware question answering.
#
# *Ultimately, this notebook allows educators, students, and developers to query lecture content interactively — creating a personalized AI teaching assistant trained on their own material.*
